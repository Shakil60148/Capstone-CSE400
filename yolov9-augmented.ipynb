# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="sgUmJcKajnsJigJKvbhR")
project = rf.workspace("machine-learning-4mojt").project("acl-and-pcl-detection")
version = project.version(1)
dataset = version.download("yolov9")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.54-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from roboflow) (2025.1.31)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.7)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.5)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (11.0.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.5->roboflow) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.5->roboflow) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.5->roboflow) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.5->roboflow) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.5->roboflow) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.5->roboflow) (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.55.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.18.5->roboflow) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.18.5->roboflow) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.18.5->roboflow) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.18.5->roboflow) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.18.5->roboflow) (2024.2.0)
# Downloading roboflow-1.1.54-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 3.0 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.3 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: filetype, python-dotenv, idna, roboflow
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# Successfully installed filetype-1.2.0 idna-3.7 python-dotenv-1.0.1 roboflow-1.1.54
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in ACL-and-PCL-Detection-1 to yolov9:: 100%|██████████| 38218/38218 [00:00<00:00, 41447.27it/s]
# Extracting Dataset Version Zip to ACL-and-PCL-Detection-1 in yolov9:: 100%|██████████| 1946/1946 [00:00<00:00, 7317.18it/s]

# %%
# %pip install ultralytics supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.78 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6170.1/8062.4 GB disk)

# %%
import os
import random
import shutil
from glob import glob

# Define dataset paths
dataset_path = "/kaggle/working/ACL-and-PCL-Detection-1"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "valid")
test_path = os.path.join(dataset_path, "test")

# Create necessary folders if they don’t exist
for folder in [train_path, valid_path, test_path]:
    os.makedirs(os.path.join(folder, "images"), exist_ok=True)
    os.makedirs(os.path.join(folder, "labels"), exist_ok=True)

# Check if dataset is already split
if len(glob(os.path.join(valid_path, "images", "*.*"))) > 0 or len(glob(os.path.join(test_path, "images", "*.*"))) > 0:
    print("⚠️ Dataset has already been split. Skipping re-splitting!")
else:
    # Get all image paths (supporting multiple formats)
    image_paths = glob(os.path.join(train_path, "images", "*.*"))  # Handles jpg, png, jpeg
    random.shuffle(image_paths)  # Shuffle images for random split

    # Define split sizes
    total_images = len(image_paths)
    test_count = int(0.2 * total_images)
    valid_count = int(0.1 * total_images)

    # Move 20% of images to test set
    for img in image_paths[:test_count]:
        label = img.replace("images", "labels").rsplit(".", 1)[0] + ".txt"
        shutil.move(img, os.path.join(test_path, "images", os.path.basename(img)))
        if os.path.exists(label):
            shutil.move(label, os.path.join(test_path, "labels", os.path.basename(label)))

    # Move 10% of images to validation set
    for img in image_paths[test_count : test_count + valid_count]:
        label = img.replace("images", "labels").rsplit(".", 1)[0] + ".txt"
        shutil.move(img, os.path.join(valid_path, "images", os.path.basename(img)))
        if os.path.exists(label):
            shutil.move(label, os.path.join(valid_path, "labels", os.path.basename(label)))

    print("✅ Dataset split completed successfully!")

# Print dataset statistics
def count_images(folder):
    return len(glob(os.path.join(folder, "images", "*.*")))

print(f"Total images in train: {count_images(train_path)}")
print(f"Total images in valid: {count_images(valid_path)}")
print(f"Total images in test: {count_images(test_path)}")
# Out:
# ✅ Dataset split completed successfully!
# Total images in train: 679
# Total images in valid: 97
# Total images in test: 194

# %%
# !yolo task=detect mode=train model=yolov9c.pt data=/kaggle/working/ACL-and-PCL-Detection-1/data.yaml epochs=60 imgsz=640 plots=True augment=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov9c.pt to 'yolov9c.pt'...
# 100%|██████████████████████████████████████| 49.4M/49.4M [00:00<00:00, 79.4MB/s]
# Ultralytics 8.3.78 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: task=detect, mode=train, model=yolov9c.pt, data=/kaggle/working/ACL-and-PCL-Detection-1/data.yaml, epochs=60, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=True, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 17.8MB/s]
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    212864  ultralytics.nn.modules.block.RepNCSPELAN4    [128, 256, 128, 64, 1]
#   3                  -1  1    164352  ultralytics.nn.modules.block.ADown           [256, 256]
#   4                  -1  1    847616  ultralytics.nn.modules.block.RepNCSPELAN4    [256, 512, 256, 128, 1]
#   5                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#   6                  -1  1   2857472  ultralytics.nn.modules.block.RepNCSPELAN4    [512, 512, 512, 256, 1]
#   7                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#   8                  -1  1   2857472  ultralytics.nn.modules.block.RepNCSPELAN4    [512, 512, 512, 256, 1]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPELAN         [512, 512, 256]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1   3119616  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 512, 512, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    912640  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 256, 256, 128, 1]
#  16                  -1  1    164352  ultralytics.nn.modules.block.ADown           [256, 256]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1   2988544  ultralytics.nn.modules.block.RepNCSPELAN4    [768, 512, 512, 256, 1]
#  19                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   3119616  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 512, 512, 256, 1]
#  22        [15, 18, 21]  1   5585884  ultralytics.nn.modules.head.Detect           [4, [256, 512, 512]]
# YOLOv9c summary: 358 layers, 25,532,316 parameters, 25,532,300 gradients, 103.7 GFLOPs
#
# Transferred 931/937 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 75.5MB/s]
# AMP: checks passed ✅
# train: Scanning /kaggle/working/ACL-and-PCL-Detection-1/train/labels... 679 imag
# train: New cache created: /kaggle/working/ACL-and-PCL-Detection-1/train/labels.cache
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.4 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /kaggle/working
14        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         97        130      0.821      0.727      0.807      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/60        11G      1.036     0.6411       1.26         20        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         97        130      0.824      0.885      0.881       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/60      11.1G      1.048     0.6685      1.269         22        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         97        130      0.864      0.816      0.872      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/60        11G      1.024     0.6481      1.252         12        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         97        130      0.675      0.779      0.758      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/60      11.1G      1.016       0.63       1.24         19        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         97        130      0.806      0.798      0.865      0.558
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/60        11G     0.9523     0.5261      1.289          9        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         97        130      0.861      0.756      0.805        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/60      11.1G     0.9414     0.5316      1.307         10        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         97        130       0.79      0.851       0.88      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/60        11G      0.879     0.4884      1.243         10        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         97        130      0.772      0.686       0.77       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/60      11.1G     0.8772     0.4891      1.241         11        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         97        130      0.875      0.729       0.81      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/60        11G     0.8549     0.4824      1.223         10        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         97        130      0.843      0.691      0.743      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/60      11.1G     0.8333     0.4664      1.204          8        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         97        130      0.806      0.722      0.763      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/60        11G     0.8097     0.4605      1.188         12        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         97        130      0.723      0.746      0.769      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/60      11.1G     0.7969     0.4463      1.181          8        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         97        130      0.738      0.729      0.766        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/60        11G     0.7749      0.438      1.154         10        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         97        130      0.851       0.73       0.76      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/60      11.1G     0.7753     0.4341      1.161          8        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         97        130      0.833      0.741      0.768      0.484
#
# 60 epochs completed in 0.707 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 51.6MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 51.6MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.78 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv9c summary (fused): 156 layers, 25,322,332 parameters, 0 gradients, 102.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         97        130      0.885      0.819      0.884      0.527
#             Normal ACL         51         51      0.875      0.964      0.954      0.647
#             Normal PCL         72         72      0.956      0.912      0.963      0.598
#               Torn ACL          5          5      0.944        0.4      0.625      0.291
#               Torn PCL          2          2      0.765          1      0.995      0.572
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# Speed: 0.2ms preprocess, 39.8ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'/kaggle/working/runs/detect/train/confusion_matrix.png', width=600)

# %%
# !yolo task=detect mode=predict model=/kaggle/working/runs/detect/train/weights/best.pt conf=0.25 source=/kaggle/working/ACL-and-PCL-Detection-1/test/images save=True
# Out:
# Ultralytics 8.3.78 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv9c summary (fused): 156 layers, 25,322,332 parameters, 0 gradients, 102.3 GFLOPs
#
# image 1/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/ax_pd_fs_101_jpg.rf.8ea09fdf0392d921fd19999f2b6754d6.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 23.1ms
# image 2/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/ax_pd_fs_102_jpg.rf.460b464676ef48de197433be79d483bc.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 23.6ms
# image 3/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/ax_pd_fs_105_jpg.rf.20511ae9b1c6a8bdc95a531b049da222.jpg: 640x640 1 Normal PCL, 1 Torn PCL, 23.5ms
# image 4/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/ax_pd_fs_108_jpg.rf.fe6cec9c4c570b8bd111b1f4cd7c27e9.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 23.8ms
# image 5/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/ax_pd_fs_109_jpg.rf.eb38314ea5124907f005673060fc3692.jpg: 640x640 1 Normal PCL, 23.8ms
# image 6/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/ax_pd_fs_132_jpg.rf.6c1262fd269207c94f33f127a155079e.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 23.5ms
# image 7/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/ax_pd_fs_136_jpg.rf.eb9bb8b0a2746c27c09639fc38b1d67b.jpg: 640x640 1 Normal PCL, 21.6ms
# image 8/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/ax_pd_fs_138_jpg.rf.962d5bae6fe04f9097dc21f7653a2744.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.7ms
# image 9/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/ax_pd_fs_152_jpg.rf.7cb551539ac90a04c2662bb69823e88c.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.7ms
# image 10/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/ax_pd_fs_164_jpg.rf.bf9ebf6bb82ba29128e1e010109a8ada.jpg: 640x640 1 Normal PCL, 21.5ms
# image 11/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/ax_pd_fs_169_jpg.rf.168acd8a28defe503cbe9566d511e596.jpg: 640x640 1 Normal PCL, 21.4ms
# image 12/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/ax_pd_fs
194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_191_jpg.rf.bb8b17f727d0ea267d5615250b928e8e.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.5ms
# image 69/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_199_jpg.rf.661d1890b2ae4fe5a3e4ffc7f6753438.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.5ms
# image 70/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_19_jpg.rf.ea225fbc408f0729968a33934ea55599.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.5ms
# image 71/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_201_jpg.rf.5dbf60a070cc550ff9a0e9ced8de9c35.jpg: 640x640 2 Normal ACLs, 1 Normal PCL, 21.6ms
# image 72/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_202_jpg.rf.66d15a4119fa8259b92715d08dccab5b.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.7ms
# image 73/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_203_jpg.rf.3d074f07b9d656fbdfac1ff8ecb69116.jpg: 640x640 1 Normal PCL, 21.6ms
# image 74/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_20_jpg.rf.9d73019a33cc1b602699613377176b0d.jpg: 640x640 1 Normal ACL, 21.6ms
# image 75/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_210_jpg.rf.66dcaf7f8974c0ab5e4f75518d9cc281.jpg: 640x640 1 Normal PCL, 1 Torn ACL, 21.6ms
# image 76/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_26_jpg.rf.9848ff273aa51501465dfe60dd36acbe.jpg: 640x640 1 Normal PCL, 21.6ms
# image 77/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_27_jpg.rf.54679fcf38feafdd6e9cec8c48d15127.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.7ms
# image 78/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_28_jpg.rf.bc41851a86c10240152d90289c794af8.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.7ms
# image 79/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_33_jpg.rf.b6bdbbc5ecebc6ecc5e9bcf238e8f9f4.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.4ms
# image 80/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_38_jpg.rf.54b8bd88a78bcda75b53fc27024920d0.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.2ms
# image 81/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_43_jpg.rf.77b431912adacda320cb7764705202d4.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.6ms
# image 82/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_61_jpg.rf.db7009a63fe2c08236a83dbed6bad25b.jpg: 640x640 1 Normal ACL, 1 Torn PCL, 21.7ms
# image 83/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_64_jpg.rf.c38e264092426f82480ed866a7a89578.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.7ms
# image 84/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_66_jpg.rf.a7b5ea252fe60bd7575b8ba69cf0938e.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.4ms
# image 85/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_70_jpg.rf.e66185ac4494720df501bab172b61854.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 1 Torn ACL, 21.4ms
# image 86/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_94_jpg.rf.42b78970404dc29e1f70f08317f9ea35.jpg: 640x640 (no detections), 21.5ms
# image 87/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_98_jpg.rf.98eb3859f61849c57baaae3edf25f8f0.jpg: 640x640 1 Normal ACL, 21.6ms
# image 88/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_t_132_jpg.rf.9964d9416dde24cdf3f15e36a05ea89e.jpg: 640x640 2 Normal ACLs, 1 Normal PCL, 21.6ms
# image 89/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_t_32_jpg.rf.d74d17d4b7823d50a4211d1f2eadde47.jpg: 640x640 1 Normal PCL, 21.3ms
# image 90/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/cor_pd_fs_t_41_jpg.rf.79248b5e729d9d6e550c2315c0fd539e.jpg: 640x640 1 Normal PCL, 1 Torn ACL, 21.7ms
# image 91/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_103_jpg.rf.aeccf37b8f2aa0172cc475e455051457.jpg: 640x640 1 Normal PCL, 21.6ms
# image 92/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_118_jpg.rf.5be1901aaae157afa432e773b6e50e1a.jpg: 640x640 1 Normal ACL, 1 Torn ACL, 21.6ms
# image 93/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_120_jpg.rf.00a07406dbc7d6966b90b4d86eb64c93.jpg: 640x640 1 Normal PCL, 21.5ms
# image 94/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_125_jpg.rf.04a3cc50bdd947c87136124334950802.jpg: 640x640 1 Normal PCL, 1 Torn ACL, 21.5ms
# image 95/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs
194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_230_jpg.rf.d563459b07a1a931eba7b2086768cd01.jpg: 640x640 1 Normal ACL, 21.5ms
# image 121/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_233_jpg.rf.e246a2c784aa0cfac31ebcb75f6e58ba.jpg: 640x640 1 Normal PCL, 21.2ms
# image 122/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_238_jpg.rf.a02b5acb1bdad70ed535d983e322c3b0.jpg: 640x640 1 Normal ACL, 21.5ms
# image 123/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_2_jpg.rf.b7e1806ea804043c6294aa8317f797f5.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.5ms
# image 124/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_46_jpg.rf.1fa299120d1a22d48c8eb450c1cd05c7.jpg: 640x640 1 Normal ACL, 21.6ms
# image 125/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_47_jpg.rf.e7a602fdd856af43a92d179c9b3362da.jpg: 640x640 1 Normal ACL, 1 Torn ACL, 21.5ms
# image 126/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_49_jpg.rf.b33f7c70feb0383f31b5d56d00f676d9.jpg: 640x640 1 Normal ACL, 21.3ms
# image 127/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_50_jpg.rf.ce9a6c3cddbc967e95b8d957b716e56c.jpg: 640x640 1 Normal PCL, 21.7ms
# image 128/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_52_jpg.rf.bd8b5279011e6717cf62765d4eba218f.jpg: 640x640 1 Normal ACL, 21.3ms
# image 129/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_53_jpg.rf.4807e77c0adec54aa98f03273cdb754c.jpg: 640x640 1 Normal ACL, 21.6ms
# image 130/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_65_jpg.rf.223006a0f08c81e89ac7778add8d1cd6.jpg: 640x640 1 Normal ACL, 21.6ms
# image 131/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_69_jpg.rf.33d3d77d5f9cacd5ba51a29ea0962f1e.jpg: 640x640 1 Normal ACL, 21.5ms
# image 132/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_70_jpg.rf.26e6d5a17d8f7d419590a414baaaf9cf.jpg: 640x640 1 Normal PCL, 21.5ms
# image 133/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_71_jpg.rf.d988892e2c201fc5f28df7ad369b7bb7.jpg: 640x640 1 Normal PCL, 21.2ms
# image 134/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_75_jpg.rf.daf01312ad66f99ab1a3053240e4216d.jpg: 640x640 1 Normal PCL, 21.6ms
# image 135/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_76_jpg.rf.3179a5bfc7b21487c206da736e94606d.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.4ms
# image 136/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_7_jpg.rf.acbec7ed41ace4013f303533fe32488d.jpg: 640x640 1 Normal ACL, 21.5ms
# image 137/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_85_jpg.rf.ba1ba490350670a5cdb91f2dfc51c543.jpg: 640x640 1 Normal PCL, 21.7ms
# image 138/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_87_jpg.rf.34bdf32d7bcfafdf78647a96fa183319.jpg: 640x640 1 Normal ACL, 21.3ms
# image 139/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_95_jpg.rf.908bf91b40e07895e9cf8ec4ba1fcbe1.jpg: 640x640 1 Normal ACL, 21.4ms
# image 140/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_96_jpg.rf.f29d6b097605070029a3a1debb6ccd96.jpg: 640x640 1 Torn ACL, 21.5ms
# image 141/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_t_10_jpg.rf.9eb9ad038ca4636cf69523ef8b40e1ae.jpg: 640x640 1 Normal PCL, 21.4ms
# image 142/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_t_151_jpg.rf.3f0bbe29eb50a532fb63a4101487cebb.jpg: 640x640 1 Normal PCL, 21.5ms
# image 143/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_t_59_jpg.rf.e5194cfc73aa0a7ca80f8835cefaeead.jpg: 640x640 1 Normal PCL, 21.5ms
# image 144/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_t_72_jpg.rf.d05303bde2773cb95295b99b0f5d564f.jpg: 640x640 (no detections), 21.6ms
# image 145/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_t_8_jpg.rf.7055d6fc5d882d7120f085062c98f6c8.jpg: 640x640 1 Normal ACL, 1 Torn ACL, 21.4ms
# image 146/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_t_pcl_114_jpg.rf.bc900c2376f5cc1aed11ab42f2ac1adf.jpg: 640x640 1 Normal ACL, 21.6ms
# image 147/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_pd_fs_t_pcl_143_jpg.rf.298b7b8fc771a944120c99652cbf9555.jpg: 640x640 1 Torn PCL, 21.6ms
# image 148/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_100_jpg.rf.52abaabe6482f859ff60d9ed843dcb65.jpg: 640x640 1 Normal PCL, 1 Torn ACL, 21.5ms
# image 149/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_119_jpg.rf.567fad1ac1cb4fdb77b254e9c6357870.jpg: 640x640 1 Normal ACL, 21.7ms
# image 150/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_120_jpg.rf.634419500a61aa64adcb5d7593a56721.jpg: 640x640 1 Normal PCL, 21.3ms
# image 151/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_124_jpg.rf.cee12a4046818f2675199860daf10bd0.jpg: 640x640 1 Normal ACL, 1 Torn ACL, 21.5ms
# image 152/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_141_jpg.rf.57ce595ecf21d0e3511e1fb13759e99c.jpg: 640x640 1 Normal ACL, 21.5ms
# image 153/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_149_jpg.rf.6c96944a85495ca91400669301d2c6b3.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.6ms
# image 154/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_14_jpg.rf.01a9c48125e667daa1e0799f7fdedc48.jpg: 640x640 1 Normal PCL, 1 Torn ACL, 21.6ms
# image 155/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_154_jpg.rf.91195248f8ec15b71eb217e38d99311b.jpg: 640x640 1 Normal PCL, 21.5ms
# image 156/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_156_jpg.rf.8ccbfdc91a0f980dd25d43c1f1bd47fc.jpg: 640x640 1 Normal PCL, 21.7ms
# image 157/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_15_jpg.rf.e142c7799c8e0ecf35f730f2c1f3eb67.jpg: 640x640 1 Normal ACL, 21.7ms
# image 158/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_160_jpg.rf.2c0a176b9ce8e5a8ab56628687b8a1e6.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.7ms
# image 159/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_169_jpg.rf.32711fc442f46a86f415f2e95be7e53f.jpg: 640x640 1 Normal ACL, 21.7ms
# image 160/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_178_jpg.rf.4a8444023da743cba5c2453f3165918a.jpg: 640x640 1 Normal PCL, 21.5ms
# image 161/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_18_jpg.rf.55b9abbe63fa54c629dc188c223d9819.jpg: 640x640 1 Normal ACL, 21.6ms
# image 162/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_19_jpg.rf.73704d0da06c9f2149799c2fcb7d8c37.jpg: 640x640 1 Normal PCL, 21.4ms
# image 163/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_202_jpg.rf.fce83c50f9a099f017968f7810bd8f3c.jpg: 640x640 1 Normal PCL, 21.7ms
# image 164/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_209_jpg.rf.442a4d7ea5e6826b8bf136efb34f958d.jpg: 640x640 1 Normal PCL, 21.7ms
# image 165/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_20_jpg.rf.26ad8f539cfdad577cb821a8b8bbd3d0.jpg: 640x640 1 Normal PCL, 21.5ms
# image 166/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_211_jpg.rf.0c204802fddb65a503acfabd37ab464d.jpg: 640x640 1 Normal ACL, 21.6ms
# image 167/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_214_jpg.rf.ba8385cd9c892d942f109897725006dc.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.5ms
# image 168/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_215_jpg.rf.59b8ec3cfa5dd3ef1d724aabaebb8b7c.jpg: 640x640 1 Normal PCL, 21.7ms
# image 169/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_217_jpg.rf.c7ec62c8e46920397d0fcadb814f3fd8.jpg: 640x640 1 Normal PCL, 21.7ms
# image 170/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_229_jpg.rf.549a121a75ea442f7a806812f7159e69.jpg: 640x640 1 Normal PCL, 21.7ms
# image 171/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_237_jpg.rf.03d8b84601eb545dbd04669a270066ae.jpg: 640x640 1 Normal ACL, 21.6ms
# image 172/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_25_jpg.rf.858f45e7de48097a05afba87a1fd7612.jpg: 640x640 1 Normal ACL, 21.5ms
# image 173/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_38_jpg.rf.2687aca8a58911a6c0feb72fc07e2a8f.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.5ms
# image 174/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_44_jpg.rf.0b7be3bd9f58194d1a74971391193160.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.7ms
# image 175/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_46_jpg.rf.247d329f53693a0e55a366cabf82dcd9.jpg: 640x640 1 Normal PCL, 21.5ms
# image 176/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_49_jpg.rf.dfb0038055d5a53d37366fdee1ffa96f.jpg: 640x640 1 Normal ACL, 21.4ms
# image 177/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_4_jpg.rf.f70ae5faec1e2a0e3589e5052f70af05.jpg: 640x640 1 Normal PCL, 21.5ms
# image 178/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_67_jpg.rf.db6ed0b408d208c5cf3d065a6fe09a41.jpg: 640x640 1 Normal PCL, 21.7ms
# image 179/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_6_jpg.rf.7bf293bb3d4de51a5064a5c4788e6fb2.jpg: 640x640 1 Normal PCL, 21.8ms
# image 180/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_72_jpg.rf.0649fe446f8ac27d303bb058485456a9.jpg: 640x640 1 Normal ACL, 1 Torn ACL, 21.6ms
# image 181/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_79_jpg.rf.5688841823396f516672a0114a153133.jpg: 640x640 1 Normal ACL, 21.7ms
# image 182/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_84_jpg.rf.e932854bdc0e1c6bb45c9d6946b59c6a.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.5ms
# image 183/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_85_jpg.rf.fe70b3be92e5108d4936b91c748c14ca.jpg: 640x640 1 Normal PCL, 21.7ms
# image 184/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_86_jpg.rf.5b8ddd82d38bb781edb71f9c1702926c.jpg: 640x640 1 Normal PCL, 21.7ms
# image 185/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_87_jpg.rf.9ce9388feabcebed533fdb3b958b6af5.jpg: 640x640 1 Normal PCL, 21.7ms
# image 186/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_90_jpg.rf.9ab7b2e90a9e054d1c930c9d148565d4.jpg: 640x640 1 Normal ACL, 21.5ms
# image 187/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_91_jpg.rf.b52a64f4896fb65fcb80462cb0ad077c.jpg: 640x640 1 Normal ACL, 21.4ms
# image 188/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_92_jpg.rf.0d67cf2a20d7587094ef97dc5245c41e.jpg: 640x640 1 Normal ACL, 1 Torn ACL, 21.7ms
# image 189/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_96_jpg.rf.f32f5b901cc1ab6905cf0a4d93691fe3.jpg: 640x640 1 Normal PCL, 21.7ms
# image 190/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_t_113_jpg.rf.97e132f24255cc497683969aeaaed5a6.jpg: 640x640 1 Normal PCL, 21.6ms
# image 191/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_t_40_jpg.rf.58e182d3fbcada186f80e37f76be68e9.jpg: 640x640 1 Normal PCL, 21.7ms
# image 192/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_t_42_jpg.rf.bbd1a97054f3132b22ecb871840b3b1a.jpg: 640x640 1 Normal ACL, 1 Normal PCL, 21.5ms
# image 193/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_t_pcl_115_jpg.rf.fe44205fce2608d12fa1077a7868c5d1.jpg: 640x640 1 Normal ACL, 1 Torn PCL, 21.5ms
# image 194/194 /kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_t_pcl_140_jpg.rf.a0b35e438d4186909e15ee6449b83a3f.jpg: 640x640 1 Normal ACL, 21.4ms
# Speed: 1.7ms preprocess, 21.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('/kaggle/working/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[:10]:
	display(IPyImage(filename=img, width=600))
	print("\n")

# %%
from IPython.display import Image as IPyImage

# Display training loss curves (accuracy, loss, and other metrics during training)
loss_curve_path = '/kaggle/working/runs/detect/train/results.png'
IPyImage(filename=loss_curve_path, width=600)

# %%
try:
    pr_curve_path = os.path.join("/kaggle/working/runs/detect/train/PR_curve.png")
    display(IPyImage(filename=pr_curve_path, width=800))
except FileNotFoundError:
    print(f"Precision-Recall curve image not found at: {pr_curve_path}")

# %%
import torch
import cv2
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO
from torchvision.transforms import Normalize

# Load trained YOLOv9 model
model_path = "/kaggle/working/runs/detect/train/weights/best.pt"  
model = YOLO(model_path)

# Select a test image
image_path = "/kaggle/working/ACL-and-PCL-Detection-1/test/images/sag_t2_154_jpg.rf.91195248f8ec15b71eb217e38d99311b.jpg"  
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Transform image for YOLOv8 inference
image_tensor = torch.tensor(image / 255.0, dtype=torch.float32).permute(2, 0, 1).unsqueeze(0)

# Hook to extract activations from the last convolutional layer
def hook_fn(module, input, output):
    global activations
    activations = output.detach()

target_layer = model.model.model[19]
target_layer.register_forward_hook(hook_fn)

# Run inference
results = model(image_tensor)
boxes = results[0].boxes  # Bounding boxes

if boxes is None or len(boxes) == 0:
    print("No objects detected!")
else:
    print("Objects detected, generating EigenCAM...")
    
    # Compute eigen decomposition on feature activations
    activation_map = activations.squeeze().cpu().numpy()
    u, s, vh = np.linalg.svd(activation_map.reshape(activation_map.shape[0], -1), full_matrices=False)
    eigen_cam = np.abs(vh[0]).reshape(activation_map.shape[1:])
    eigen_cam = (eigen_cam - eigen_cam.min()) / (eigen_cam.max() - eigen_cam.min())  # Normalize
    eigen_cam = cv2.resize(eigen_cam, (image.shape[1], image.shape[0]))
    
    # Overlay heatmap on original image
    heatmap = cv2.applyColorMap(np.uint8(255 * eigen_cam), cv2.COLORMAP_JET)
    overlay = cv2.addWeighted(image, 0.6, heatmap, 0.4, 0)
    
    # Display both original image and EigenCAM side by side
    plt.figure(figsize=(12, 6))
    
    # Original Image
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.axis("off")
    plt.title("Original Image")
    
    # EigenCAM Overlay
    plt.subplot(1, 2, 2)
    plt.imshow(overlay)
    plt.axis("off")
    plt.title("EigenCAM Visualization")
    
    plt.show()
# Out:
# 0: 640x640 1 Normal PCL, 23.9ms
# Speed: 1.4ms preprocess, 23.9ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
# Objects detected, generating EigenCAM...
